# %%
# %pip install langchain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain
#   Downloading langchain-0.3.14-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from langchain) (6.0.2)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.37-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.11.11-cp313-cp313-win_amd64.whl.metadata (8.0 kB)
# Collecting langchain-core<0.4.0,>=0.3.29 (from langchain)
#   Downloading langchain_core-0.3.30-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.3 (from langchain)
#   Downloading langchain_text_splitters-0.3.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.3,>=0.1.17 (from langchain)
#   Downloading langsmith-0.2.11-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from langchain) (2.2.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from langchain) (2.10.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<10,>=8.1.0 (from langchain)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.5.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.1.0-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading propcache-0.2.1-cp313-cp313-win_amd64.whl.metadata (9.5 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.18.3-cp313-cp313-win_amd64.whl.metadata (71 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.29->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from langsmith<0.3,>=0.1.17->langchain) (0.27.2)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.3,>=0.1.17->langchain)
#   Downloading orjson-3.10.14-cp313-cp313-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.3,>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.1.1-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: anyio in c:\users\jatro\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\users\jatro\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: sniffio in c:\users\jatro\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jatro\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain) (3.0.0)
# Downloading langchain-0.3.14-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 981.2 kB/s eta 0:00:01
#    ------------------------------- -------- 0.8/1.0 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.2 MB/s eta 0:00:00
# Downloading aiohttp-3.11.11-cp313-cp313-win_amd64.whl (436 kB)
# Downloading langchain_core-0.3.30-py3-none-any.whl (411 kB)
# Downloading langchain_text_splitters-0.3.5-py3-none-any.whl (31 kB)
# Downloading langsmith-0.2.11-py3-none-any.whl (326 kB)
# Downloading SQLAlchemy-2.0.37-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 3.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.7 MB/s eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.5.0-cp313-cp313-win_amd64.whl (51 kB)
# Downloading greenlet-3.1.1-cp313-cp313-win_amd64.whl (299 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.1.0-cp313-cp313-win_amd64.whl (28 kB)
# Downloading orjson-3.10.14-cp313-cp313-win_amd64.whl (133 kB)
# Downloading propcache-0.2.1-cp313-cp313-win_amd64.whl (43 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading yarl-1.18.3-cp313-cp313-win_amd64.whl (315 kB)
# Installing collected packages: tenacity, propcache, orjson, multidict, jsonpatch, greenlet, frozenlist, aiohappyeyeballs, yarl, SQLAlchemy, requests-toolbelt, aiosignal, langsmith, aiohttp, langchain-core, langchain-text-splitters, langchain
# Successfully installed SQLAlchemy-2.0.37 aiohappyeyeballs-2.4.4 aiohttp-3.11.11 aiosignal-1.3.2 frozenlist-1.5.0 greenlet-3.1.1 jsonpatch-1.33 langchain-0.3.14 langchain-core-0.3.30 langchain-text-splitters-0.3.5 langsmith-0.2.11 multidict-6.1.0 orjson-3.10.14 propcache-0.2.1 requests-toolbelt-1.0.0 tenacity-9.0.0 yarl-1.18.3

# %%
import langchain

# %%
langchain.__version__
# Out:
# '0.3.14'

# %%
"""
a
b
c
d
e

"""
# Out:
# '\na\nb\nc\nd\ne\n\n'

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
turkey_string = """
Turkey,[a] officially the Republic of Türkiye,[b] is a country mainly located in Anatolia in West Asia, with a smaller part called East Thrace in Southeast Europe. It borders the Black Sea to the north; Georgia, Armenia, Azerbaijan, and Iran to the east; Iraq, Syria, and the Mediterranean Sea to the south; and the Aegean Sea, Greece, and Bulgaria to the west. Turkey is home to over 85 million people; most are ethnic Turks, while ethnic Kurds are the largest ethnic minority.[5] Officially a secular state, Turkey has a Muslim-majority population. Ankara is Turkey's capital and second-largest city, while Istanbul is its largest city and economic and financial center. Other major cities include İzmir, Bursa, and Antalya.
"""

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 30,
    chunk_overlap = 10
)

# %%
chunks = splitter.split_text(turkey_string)

# %%
len(chunks)
# Out:
# 3

# %%
chunks[0]
len(chunks[0])
chunks[1]
len(chunks[1])
# Out:
# 289

# %%
for i, chunk in enumerate(chunks):
    print(f"Chunk {i}:")
    print(chunk)
    print("\n\n")
# Out:
# Chunk 0:
# Turkey,[a] officially the Republic of Türkiye,[b] is a country mainly located in Anatolia in West Asia, with a smaller part called East Thrace in Southeast Europe. It borders the Black Sea to the north; Georgia, Armenia, Azerbaijan, and Iran to the east; Iraq, Syria, and the Mediterranean Sea to
#
#
#
# Chunk 1:
# east; Iraq, Syria, and the Mediterranean Sea to the south; and the Aegean Sea, Greece, and Bulgaria to the west. Turkey is home to over 85 million people; most are ethnic Turks, while ethnic Kurds are the largest ethnic minority.[5] Officially a secular state, Turkey has a Muslim-majority
#
#
#
# Chunk 2:
# a secular state, Turkey has a Muslim-majority population. Ankara is Turkey's capital and second-largest city, while Istanbul is its largest city and economic and financial center. Other major cities include İzmir, Bursa, and Antalya.
